# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
import os 
import seaborn as sns
import matplotlib.pyplot as plt 
from plotly.subplots import make_subplots

os.getcwd()
# Out:
# 'c:\\Users\\seong\\Desktop\\Enittproj\\Enitt'

# %%
def load_data(path):

    df = pd.read_csv(path, encoding="utf-8")
    # df = pd.read_csv("./마지막데이터/banpo1_power_weather_df.csv", encoding="utf-8")
    df = df[~(df["합계 일사량(MJ/m2)"].isna() == True)]


    df_need_1 = df[["env_slopesolar", "watt", "reset_match", "match_solar"]]
    df_need_2 = df[["env_slopesolar", "최저기온(°C)", "최고기온(°C)", "일강수량(mm)", "평균 풍속(m/s)","평균 상대습도(%)", "가조시간(hr)","평균 전운량(1/10)",  "watt", "reset_match","match_solar"]]
    df_need_2.columns = ["env_slopesolar", "최저기온", "최고기온", "일강수량", "평균풍속", "평균상대습도", "가조시간", "평균전운량", "watt", "reset_match", "match_solar"]

    df_need_1
    df_need_2 = df_need_2.fillna(0)

    return df_need_1, df_need_2
# 훈련정확도 :  0.9690061868299032
# 예측정확도 :  0.741636215246966
# 훈련정확도2 :  0.9814094267696867
# 예측정확도2 :  0.8665745450264063

SOLAR="reset_match"

# %%
df_need_1, df_need_2 = load_data("./마지막데이터/total_enitt_data2.csv")

# SOLAR = "match_solar"
# %run ./make_model.ipynb
# linear -( t검정) , svr, random mape, 결정계수, R^2 정확도 -> MAPE  
# 
# STATS LINEAR REGRESSION-> OLS, SUMMARY-> 진단, X 변수 FEATURE ENGINERRING ( AIC 낮음 )
# Out:
# 일사량 =>  reset_match
# ----------LinearRegression----------
# 훈련정확도 :  0.8123664398200403
# 예측정확도 :  0.811090843408357
# 훈련정확도2 :  0.8225268391716325
# 예측정확도2 :  0.8237637041953374
# ----------SVR----------
# 훈련정확도 :  0.44033092403581464
# 예측정확도 :  0.43397978129214965
# 훈련정확도2 :  0.43686707462862073
# 예측정확도2 :  0.4314148312144176
# ----------GradientBoosting----------
# 훈련정확도 :  0.8503921009771822
# 예측정확도 :  0.7956647678913759
# 훈련정확도2 :  0.895026029398661
# 예측정확도2 :  0.8476538880788957
# ----------DecisionTree----------
# 훈련정확도 :  0.9998100773725063
# 예측정확도 :  0.6321849187563826
# 훈련정확도2 :  0.9999665759119487
# 예측정확도2 :  0.6503882372436758
# ----------RandomForest----------
# 훈련정확도 :  0.963407798854621
# 예측정확도 :  0.7314684361495811
# 훈련정확도2 :  0.9805046805554111
# 예측정확도2 :  0.8423277628290089
# MAPE :  inf
# 중요도 일사량, 기온, 기온, 강수량, 풍속, 습도, 가조시간, 전운량 [0.85019708 0.01776322 0.0226492  0.00553877 0.03053765 0.0295203
#  0.02462623 0.01916756]

# %%
df_need_1, df_need_2 = load_data("./마지막데이터/banpo1_power_weather_df.csv")
# %run ./make_model.ipynb
# Out:
# 일사량 =>  match_solar
# ----------LinearRegression----------
# 훈련정확도 :  0.9638512330970541
# 예측정확도 :  0.9720486456832568
# 훈련정확도2 :  0.965090178669457
# 예측정확도2 :  0.9699919568289377
# ----------SVR----------
# 훈련정확도 :  0.13147764676780582
# 예측정확도 :  0.11358686196104606
# 훈련정확도2 :  0.11496182512958142
# 예측정확도2 :  0.10385588844532645
# ----------GradientBoosting----------
# 훈련정확도 :  0.9854609357184407
# 예측정확도 :  0.9685938617615466
# 훈련정확도2 :  0.9923339967101844
# 예측정확도2 :  0.9700773734467671
# ----------DecisionTree----------
# 훈련정확도 :  0.9971829129844287
# 예측정확도 :  0.9553222264211609
# 훈련정확도2 :  1.0
# 예측정확도2 :  0.9377760390407887
# ----------RandomForest----------
# 훈련정확도 :  0.9911957867826459
# 예측정확도 :  0.9585321561223495
# 훈련정확도2 :  0.9935103311101245
# 예측정확도2 :  0.9641082093124403
# MAPE :  119.54309586539577
# 중요도 일사량, 기온, 기온, 강수량, 풍속, 습도, 가조시간, 전운량 [9.80732089e-01 3.49164786e-03 3.84893217e-03 5.23281794e-04
#  2.87660897e-03 2.94917155e-03 2.20064330e-03 3.37762538e-03]

# %%
df_need_1, df_need_2 = load_data("./마지막데이터/LH1_power_weather_df.csv")
# %run ./make_model.ipynb
# Out:
# 일사량 =>  match_solar
# ----------LinearRegression----------
# 훈련정확도 :  0.933332829481807
# 예측정확도 :  0.952569929268536
# 훈련정확도2 :  0.9375979600422213
# 예측정확도2 :  0.9467660129846707
# ----------SVR----------
# 훈련정확도 :  0.0480305515418864
# 예측정확도 :  -0.06424563171717801
# 훈련정확도2 :  0.03977201675371178
# 예측정확도2 :  -0.07233402154387458
# ----------GradientBoosting----------
# 훈련정확도 :  0.9776047137637085
# 예측정확도 :  0.9389798428102883
# 훈련정확도2 :  0.991312334273457
# 예측정확도2 :  0.9367063305604377
# ----------DecisionTree----------
# 훈련정확도 :  0.9992468818445694
# 예측정확도 :  0.9161506422995174
# 훈련정확도2 :  1.0
# 예측정확도2 :  0.8998111267133979
# ----------RandomForest----------
# 훈련정확도 :  0.9860558372364285
# 예측정확도 :  0.9356535980399157
# 훈련정확도2 :  0.9909238244818562
# 예측정확도2 :  0.9398790237166623
# MAPE :  879.4919047519307
# 중요도 일사량, 기온, 기온, 강수량, 풍속, 습도, 가조시간, 전운량 [0.95423575 0.00470226 0.00561701 0.00150706 0.00561833 0.00857499
#  0.00992505 0.00981953]

# %%
df_need_1, df_need_2 = load_data("./마지막데이터/ongok_power_weather_df.csv")
# %run ./make_model.ipynb
# Out:
# 일사량 =>  match_solar
# ----------LinearRegression----------
# 훈련정확도 :  0.9698801051655276
# 예측정확도 :  0.980388933743109
# 훈련정확도2 :  0.973608033775965
# 예측정확도2 :  0.9791203648386352
# ----------SVR----------
# 훈련정확도 :  0.042256620874124184
# 예측정확도 :  0.04370231121440371
# 훈련정확도2 :  0.03648851169778522
# 예측정확도2 :  0.03826882458314096
# ----------GradientBoosting----------
# 훈련정확도 :  0.991278383630252
# 예측정확도 :  0.9594302328649016
# 훈련정확도2 :  0.9972362989896258
# 예측정확도2 :  0.9639886599902833
# ----------DecisionTree----------
# 훈련정확도 :  0.99925051509747
# 예측정확도 :  0.9378206003974642
# 훈련정확도2 :  1.0
# 예측정확도2 :  0.9569641606818863
# ----------RandomForest----------
# 훈련정확도 :  0.9930865489532275
# 예측정확도 :  0.9564914216867298
# 훈련정확도2 :  0.9946395808824017
# 예측정확도2 :  0.9685609465405592
# MAPE :  94.05194216595568
# 중요도 일사량, 기온, 기온, 강수량, 풍속, 습도, 가조시간, 전운량 [9.79380891e-01 2.81389879e-03 2.73304640e-03 7.53065316e-04
#  3.56480630e-03 2.94632944e-03 4.79929821e-03 3.00866454e-03]

# %%
df_need_1, df_need_2 = load_data("./마지막데이터/geumgang1_power_weather_df.csv")
# %run ./make_model.ipynb
# Out:
# 일사량 =>  match_solar
# ----------LinearRegression----------
# 훈련정확도 :  0.8154796867664247
# 예측정확도 :  0.9676339814066319
# 훈련정확도2 :  0.8318096654314514
# 예측정확도2 :  0.9699774624915909
# ----------SVR----------
# 훈련정확도 :  0.024750078211493554
# 예측정확도 :  0.04084810399354766
# 훈련정확도2 :  0.019843699085600353
# 예측정확도2 :  0.033106328149534514
# ----------GradientBoosting----------
# 훈련정확도 :  0.9853973413661302
# 예측정확도 :  0.7304311829289596
# 훈련정확도2 :  0.9946918707827955
# 예측정확도2 :  0.9285265555916632
# ----------DecisionTree----------
# 훈련정확도 :  0.9986498450240193
# 예측정확도 :  0.6489971494192066
# 훈련정확도2 :  1.0
# 예측정확도2 :  0.4919802403311988
# ----------RandomForest----------
# 훈련정확도 :  0.9616568284812047
# 예측정확도 :  0.8330424557441657
# 훈련정확도2 :  0.9637063586302465
# 예측정확도2 :  0.9430195911307561
# MAPE :  inf
# 중요도 일사량, 기온, 기온, 강수량, 풍속, 습도, 가조시간, 전운량 [0.92193001 0.00913643 0.00891886 0.0075332  0.01734587 0.01483751
#  0.01277438 0.00752375]

# %%
df_need_1, df_need_2 = load_data("./마지막데이터/NewREC1_power_weather_df.csv")
# %run ./make_model.ipynb
# Out:
# 일사량 =>  match_solar
# ----------LinearRegression----------
# 훈련정확도 :  0.6221281101613381
# 예측정확도 :  0.7043674683698968
# 훈련정확도2 :  0.6783698414651257
# 예측정확도2 :  0.7509393668063485
# ----------SVR----------
# 훈련정확도 :  0.09365163501760254
# 예측정확도 :  0.1079543129989966
# 훈련정확도2 :  0.07904845961538642
# 예측정확도2 :  0.09308633182587223
# ----------GradientBoosting----------
# 훈련정확도 :  0.8408688090149357
# 예측정확도 :  0.7509924688179106
# 훈련정확도2 :  0.948693239065341
# 예측정확도2 :  0.7796034243379827
# ----------DecisionTree----------
# 훈련정확도 :  0.9721014276319623
# 예측정확도 :  0.4798672141760455
# 훈련정확도2 :  1.0
# 예측정확도2 :  0.5387232304839749
# ----------RandomForest----------
# 훈련정확도 :  0.9219621617172093
# 예측정확도 :  0.6398100093713897
# 훈련정확도2 :  0.9743390071688889
# 예측정확도2 :  0.8021373333355943
# MAPE :  inf
# 중요도 일사량, 기온, 기온, 강수량, 풍속, 습도, 가조시간, 전운량 [0.75918772 0.02915652 0.04299167 0.00975312 0.03733533 0.02045112
#  0.07514396 0.02598056]

# %%
df_need_1, df_need_2 = load_data("./마지막데이터/zumun8ho1_power_weather_df.csv")
# %run ./make_model.ipynb
# Out:
# 일사량 =>  match_solar
# ----------LinearRegression----------
# 훈련정확도 :  0.9822494565832602
# 예측정확도 :  0.9797485120054003
# 훈련정확도2 :  0.9861481973076864
# 예측정확도2 :  0.9763473162463013
# ----------SVR----------
# 훈련정확도 :  0.026116442887089697
# 예측정확도 :  -0.0323778934666874
# 훈련정확도2 :  0.02194664647603428
# 예측정확도2 :  -0.03866718031395355
# ----------GradientBoosting----------
# 훈련정확도 :  0.997371892761696
# 예측정확도 :  0.9724746744537278
# 훈련정확도2 :  0.9995129818554029
# 예측정확도2 :  0.9803625239044198
# ----------DecisionTree----------
# 훈련정확도 :  0.9999728211145887
# 예측정확도 :  0.9630548325490513
# 훈련정확도2 :  1.0
# 예측정확도2 :  0.9589083339613238
# ----------RandomForest----------
# 훈련정확도 :  0.9963347702732376
# 예측정확도 :  0.9750251661171438
# 훈련정확도2 :  0.9967471438338137
# 예측정확도2 :  0.9794099033193031
# MAPE :  159.26231041239717
# 중요도 일사량, 기온, 기온, 강수량, 풍속, 습도, 가조시간, 전운량 [0.98765434 0.00148775 0.0029011  0.00157593 0.00123526 0.00193242
#  0.00157996 0.00163322]

# %%
df_need_1, df_need_2 = load_data("./마지막데이터/banpo1_power_weather_df.csv")
other_data = pd.read_csv("./마지막데이터/수원_서산_영동.csv", encoding="ms949")
# other_data
other_data_need = other_data[['합계 일사량(W/m2)', '최저기온(°C)', '최고기온(°C)', '일강수량(mm)','평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)','평균 전운량(1/10)', '설비용량에따른총발전량(Wh/kW)']]
other_data_need.columns = ["일사량", "최저기온", "최고기온", "일강수량", "평균풍속", "평균상대습도", "가조시간", "전운량", "watt"]


def load_data1(df):

    # df = pd.read_csv("./마지막데이터/banpo1_power_weather_df.csv", encoding="utf-8")

    df_need_1 = df[["일사량", "watt"]]
    df_need_1.columns = ["env_slopesolar", "watt"]
    df_need_2 = df[["일사량", "최저기온", "최고기온", "일강수량", "평균풍속", "평균상대습도", "가조시간", "전운량", "watt"]]
    df_need_2.columns = ["env_slopesolar", "최저기온", "최고기온", "일강수량", "평균풍속", "평균상대습도", "가조시간", "평균전운량", "watt"]

    df_need_1
    df_need_2 = df_need_2.fillna(0)

    return df_need_1, df_need_2

df_need_1, df_need_2 =load_data1(other_data_need)

SOLAR = "env_slopesolar"
# print(df_need_1.describe())
# print("-----------")
# print(df_need_11.describe())
# # df_need_1



##############################

# %run ./make_model.ipynb


# SOLAR = "env_slopesolar"
# %run ./make_model.ipynb
# Out:
# 일사량 =>  env_slopesolar
# ----------LinearRegression----------
# 훈련정확도 :  0.6173280479165346
# 예측정확도 :  0.6672389329565745
# 훈련정확도2 :  0.6524684823805922
# 예측정확도2 :  0.7069915749467091
# ----------SVR----------
# 훈련정확도 :  0.2508394230864902
# 예측정확도 :  0.2713173842463702
# 훈련정확도2 :  0.23318102356202675
# 예측정확도2 :  0.24842507168009764
# ----------GradientBoosting----------
# 훈련정확도 :  0.7045932327118467
# 예측정확도 :  0.6902268867753848
# 훈련정확도2 :  0.7970700227105906
# 예측정확도2 :  0.7659599651086774
# ----------DecisionTree----------
# 훈련정확도 :  0.8902299032015262
# 예측정확도 :  0.3856193113161408
# 훈련정확도2 :  1.0
# 예측정확도2 :  0.39150249097159506
# ----------RandomForest----------
# 훈련정확도 :  0.8563190481592557
# 예측정확도 :  0.5522425833778593
# 훈련정확도2 :  0.9591940462194818
# 예측정확도2 :  0.7489718546237536
# MAPE :  inf
# 중요도 일사량, 기온, 기온, 강수량, 풍속, 습도, 가조시간, 전운량 [0.70417126 0.04237976 0.04703636 0.01173626 0.02826449 0.05798473
#  0.04674024 0.06168689]
