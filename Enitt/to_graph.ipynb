# %%
import pandas as pd 
import numpy as np

# %%
asdf = pd.read_csv("./ENITT_SOLAR_DATA/ENITT_SOLAR_DATA/365. 반포써밋2블럭 발전량.csv")

asdf
# Out:
#         pow_index  pow_id    pow_date  pow_time  pow_cap  pow_dcv     pow_dca  \
# 0               1       2  2018-10-18  14:35:09     15.0      439   10.000000
# 1               2       2  2018-10-18  14:36:21     15.0      435    9.800000
# 2               3       2  2018-10-18  14:37:18     15.0      444    9.600000
# 3               4       2  2018-10-18  14:38:10     15.0      453    9.300000
# 4               5       2  2018-10-18  14:39:03     15.0      454    9.200000
# ...           ...     ...         ...       ...      ...      ...         ...
# 395904     395905       2  2020-04-24  19:45:02     15.0      451  147.055588
# 395905     395906       2  2020-04-24  20:06:02     15.0      451  147.055588
# 395906     395907       2  2020-04-24  20:10:02     15.0      451  147.055588
# 395907     395908       2  2020-04-24  20:28:09     15.0      451  147.055588
# 395908     395909       2  2020-04-24  20:34:02     15.0      451  147.055588
#
# ...

# %%
asdf["pow_date"].unique()
# Out:
# array(['2018-10-18', '2018-10-19', '2018-10-20', '2018-10-21',
#        '2018-10-22', '2018-10-23', '2018-10-24', '2018-10-25',
#        '2018-10-26', '2018-10-27', '2018-10-28', '2018-10-29',
#        '2018-10-30', '2018-10-31', '2018-11-01', '2018-11-02',
#        '2018-11-03', '2018-11-04', '2018-11-05', '2018-11-06',
#        '2018-11-07', '2018-11-08', '2018-11-09', '2018-11-10',
#        '2018-11-11', '2018-11-12', '2018-11-13', '2018-11-14',
#        '2018-11-15', '2018-11-16', '2018-11-17', '2018-11-18',
#        '2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22',
#        '2018-11-23', '2018-11-24', '2018-11-25', '2018-11-26',
#        '2018-11-27', '2018-11-28', '2018-11-29', '2018-11-30',
#        '2018-12-01', '2018-12-02', '2018-12-03', '2018-12-04',
#        '2018-12-05', '2018-12-06', '2018-12-07', '2018-12-08',
#        '2018-12-09', '2018-12-10', '2018-12-11', '2018-12-12',
#        '2018-12-13', '2018-12-14', '2018-12-15', '2018-12-16',
# ...
